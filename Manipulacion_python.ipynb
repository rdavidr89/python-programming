# %% [markdown]
# <a href="https://colab.research.google.com/github/rdavidr89/python-programming/blob/main/Manipulacion_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Descargar el documento encontrado en el siguiente link https://www.kaggle.com/datasets/gpreda/covid-world-vaccination-progress?resource=download
# #Cargar el documento en la carpeta de google colab llamada sample_data
# #correr los codigos

# %% [markdown]
# a) Extraer la informacion del archivo

# %%
import pandas as pd
vacunacion=pd.read_csv('/content/sample_data/country_vaccinations.csv')
vacunacion
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 86507     Zimbabwe      ZWE  2022-03-25           8691642.0
# 86508     Zimbabwe      ZWE  2022-03-26           8791728.0
# 86509     Zimbabwe      ZWE  2022-03-27           8845039.0
# 86510     Zimbabwe      ZWE  2022-03-28           8934360.0
# 86511     Zimbabwe      ZWE  2022-03-29           9039729.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# ...

# %% [markdown]
# b)Mostrar la estructura y tipos de datos de cada columna para identificar qué operaciones puedes realizar con cada una de ellas, asegurándote que las columnas con fechas sean del tipo datetime64.

# %%
import pandas as pd
vacunacion=pd.read_csv('/content/sample_data/country_vaccinations.csv')
vacunacion['date']=pd.to_datetime(vacunacion['date'])
vacunacion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86512 entries, 0 to 86511
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              86512 non-null  object
#  1   iso_code                             86512 non-null  object
#  2   date                                 86512 non-null  datetime64[ns]
#  3   total_vaccinations                   43607 non-null  float64
#  4   people_vaccinated                    41294 non-null  float64
#  5   people_fully_vaccinated              38802 non-null  float64
#  6   daily_vaccinations_raw               35362 non-null  float64
#  7   daily_vaccinations                   86213 non-null  float64
#  8   total_vaccinations_per_hundred       43607 non-null  float64
#  9   people_vaccinated_per_hundred        41294 non-null  float64
#  10  people_fully_vaccinated_per_hundred  38802 non-null  float64
# ...

# %% [markdown]
# c. Determinar la cantidad de vacunas aplicadas de cada compañía (con base en cómo lo reporta cada país en la columna vaccines, en otras palabras, agrupe por vaccines y realice la sumatoria).

# %%
import pandas as pd
vacunacion=pd.read_csv('/content/sample_data/country_vaccinations.csv')
vacunacion[['vaccines','daily_vaccinations']].groupby('vaccines').sum()
# Out:
#                                                     daily_vaccinations
# vaccines
# Abdala, Johnson&Johnson, Oxford/AstraZeneca, Pf...           9616160.0
# Abdala, Moderna, Oxford/AstraZeneca, Pfizer/Bio...         201816053.0
# Abdala, Sinopharm/Beijing, Sinovac, Soberana02,...          37861146.0
# Abdala, Soberana Plus, Soberana02                           33802957.0
# COVIran Barekat, Covaxin, FAKHRAVAC, Oxford/Ast...         146357015.0
# ...                                                                ...
# Pfizer/BioNTech, Sinovac, Turkovac                         147484328.0
# Pfizer/BioNTech, Sputnik V                                     68643.0
# QazVac, Sinopharm/Beijing, Sputnik V                        20891256.0
# Sinopharm/Beijing                                             893824.0
# Sinopharm/Beijing, Sputnik V                                14398697.0
#
# [84 rows x 1 columns]

# %% [markdown]
# d. Obtener la cantidad de vacunas aplicadas en todo el mundo.

# %%
import pandas as pd
vacunacion=pd.read_csv('/content/sample_data/country_vaccinations.csv')
print('la cantidad de vacunas aplicadas en todo el mundo es:',vacunacion['total_vaccinations'].sum())
# Out:
# la cantidad de vacunas aplicadas en todo el mundo es: 2002854013761.0

# %% [markdown]
# e. Calcular el promedio de vacunas aplicadas por país.

# %%
import pandas as pd
vacunacion=pd.read_csv('/content/sample_data/country_vaccinations.csv')
vacunacion[['country','total_vaccinations']].groupby('country').mean()
# Out:
#                    total_vaccinations
# country
# Afghanistan              2.566118e+06
# Albania                  1.191695e+06
# Algeria                  9.956086e+06
# Andorra                  5.827721e+04
# Angola                   6.074066e+06
# ...                               ...
# Wales                    4.132861e+06
# Wallis and Futuna        9.142925e+03
# Yemen                    4.794049e+05
# Zambia                   1.048484e+06
# Zimbabwe                 4.181618e+06
#
# [223 rows x 1 columns]

# %% [markdown]
# f. Determinar la cantidad de vacunas aplicadas el día 29/01/21 en todo el mundo.

# %%
import pandas as pd
vacunacion=pd.read_csv('/content/sample_data/country_vaccinations.csv')
vacunacion['date']=pd.to_datetime(vacunacion['date'])
suma_de_vacunaciones=vacunacion[vacunacion['date'].isin(['29/1/21'])]
print('la cantidad de vacunas aplicadas en la fecha 29/01/2021 es:',suma_de_vacunaciones['people_vaccinated'].sum())
# Out:
# la cantidad de vacunas aplicadas en la fecha 29/01/2021 es: 65432091.0

# %% [markdown]
# g. Crear un dataframe nuevo denominado conDiferencias que contenga los datos originales y una columna derivada (diferencias) con las diferencias de aplicación entre las columnas daily_vaccionations y daily_vaccionations_raw.

# %%
import pandas as pd
vacunacion=pd.read_csv('/content/sample_data/country_vaccinations.csv')
vacunacion['diferencias']=vacunacion['daily_vaccinations']-vacunacion['daily_vaccinations_raw']
conDiferencias=vacunacion[['daily_vaccinations','daily_vaccinations_raw','diferencias']]
conDiferencias
# Out:
#        daily_vaccinations  daily_vaccinations_raw  diferencias
# 0                     NaN                     NaN          NaN
# 1                  1367.0                     NaN          NaN
# 2                  1367.0                     NaN          NaN
# 3                  1367.0                     NaN          NaN
# 4                  1367.0                     NaN          NaN
# ...                   ...                     ...          ...
# 86507             69579.0                139213.0     -69634.0
# 86508             83429.0                100086.0     -16657.0
# 86509             90629.0                 53311.0      37318.0
# 86510            100614.0                 89321.0      11293.0
# 86511            103751.0                105369.0      -1618.0
#
# [86512 rows x 3 columns]

# %% [markdown]
# h. Obtener el periodo de tiempo entre el registro con fecha más reciente y el registro con fecha más antigua.

# %%
import pandas as pd
vacunacion=pd.read_csv('/content/sample_data/country_vaccinations.csv')
vacunacion['date']=pd.to_datetime(vacunacion['date'])
fechas_min_max=vacunacion['date'].agg(['min','max'])
dif_fechas=vacunacion['date'].max()-vacunacion['date'].min()
print('fecha minima y maxima del dataframe son:',fechas_min_max)
print('Periodo de tiempo entre fecha minima y maxima es:',dif_fechas)

# %% [markdown]
# i. Crear un dataframe nuevo denominado conCantidad que contenga los datos originales y una columna derivada (canVac) con la cantidad de vacunas utilizadas cada día (usar la columna vaccines y separar por el carácter , ).

# %%
import pandas as pd
vacunacion=pd.read_csv('/content/sample_data/country_vaccinations.csv')
vacunacion['canVac']=vacunacion['vaccines'].str.split(',').str.len()
conCantidad=vacunacion[['vaccines','canVac']]
conCantidad
# Out:
#                                                 vaccines  canVac
# 0      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...       4
# 1      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...       4
# 2      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...       4
# 3      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...       4
# 4      Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...       4
# ...                                                  ...     ...
# 86507  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...       4
# 86508  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...       4
# 86509  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...       4
# 86510  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...       4
# 86511  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...       4
#
# [86512 rows x 2 columns]

# %% [markdown]
# j. Generar un dataframe denominado antes20 con todos los registros que se hayan realizado antes del 20 de diciembre de 2020.

# %%
import pandas as pd
vacunacion=pd.read_csv('/content/sample_data/country_vaccinations.csv')
vacunacion['date']=pd.to_datetime(vacunacion['date'])
antes20=vacunacion.query('date<"2020/12/20"')
antes20
# Out:
#              country iso_code       date  total_vaccinations  \
# 13403         Canada      CAN 2020-12-14                 5.0
# 13404         Canada      CAN 2020-12-15               727.0
# 13405         Canada      CAN 2020-12-16              3025.0
# 13406         Canada      CAN 2020-12-17              7279.0
# 13407         Canada      CAN 2020-12-18             11296.0
# ...              ...      ...        ...                 ...
# 82362  United States      USA 2020-12-15             84638.0
# 82363  United States      USA 2020-12-16            244549.0
# 82364  United States      USA 2020-12-17            517161.0
# 82365  United States      USA 2020-12-18            933551.0
# 82366  United States      USA 2020-12-19           1115437.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 13403                5.0                      NaN                     NaN
# 13404              727.0                      NaN                   722.0
# ...

# %% [markdown]
# k. Obtener un dataframe denominado pfizer con todos los registros donde se haya utilizado la vacuna Pfizer.

# %%
import pandas as pd
vacunacion=pd.read_csv('/content/sample_data/country_vaccinations.csv')
pfizer=vacunacion[vacunacion['vaccines'].isin(['Pfizer/BioNTech'])]
pfizer
# Out:
#                         country iso_code        date  total_vaccinations  \
# 3652                      Aruba      ABW  2021-03-29             25766.0
# 3653                      Aruba      ABW  2021-03-30                 NaN
# 3654                      Aruba      ABW  2021-03-31                 NaN
# 3655                      Aruba      ABW  2021-04-01                 NaN
# 3656                      Aruba      ABW  2021-04-02                 NaN
# ...                         ...      ...         ...                 ...
# 80548  Turks and Caicos Islands      TCA  2022-03-21                 NaN
# 80549  Turks and Caicos Islands      TCA  2022-03-22                 NaN
# 80550  Turks and Caicos Islands      TCA  2022-03-23                 NaN
# 80551  Turks and Caicos Islands      TCA  2022-03-24                 NaN
# 80552  Turks and Caicos Islands      TCA  2022-03-25             68670.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# ...

# %% [markdown]
# l. Almacenar los dataframes generados (conDiferencias, conCantidad, antes20 y pfizer) en un archivo de Excel denominado resultadosReto.xlsx, donde cada dataframe ocupe una hoja diferente. Se recomienda ver la documentación de pd.ExcelWriter.

# %%
#Agregar el path de la carpeta google colab encontrada en el google drive.
#En caso de que se quiera guardar en otra carpeta de google drive copiar el path
#sustituirlo en la primera linea del código dentro de las comillas
#y agregar al final del path lo siguiente: /resultadosReto.xlsx. cerrar las comillas
#Procurar correr todos los codigos antes de usar este codigo para evitar error
with pd.ExcelWriter('/content/drive/MyDrive/Colab Notebooks/resultadosReto.xlsx') as writer:
  conDiferencias.to_excel(writer, sheet_name='Respuesta_g')
  conCantidad.to_excel(writer, sheet_name='Respuesta_i')
  antes20.to_excel(writer, sheet_name='Respuesta_j')
  pfizer.to_excel(writer, sheet_name='Respuesta_k')
